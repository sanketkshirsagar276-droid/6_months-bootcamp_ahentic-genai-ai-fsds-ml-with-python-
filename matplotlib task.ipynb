# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
x1 = np.linspace(0,10,50)
plt.plot(x1, np.sin(x1), '-')
plt.plot(x1, np.cos(x1), '--')
plt.show()

# %%
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1), '*')
plt.show()

# %%
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1), '*')

plt.show()

# %%
plt.figure()

plt.subplot(2, 1, 1)   # (rows, columns, panel number
plt.plot(x1, np.sin(x1))

plt.subplot(2, 1, 2)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1));
plt.show()

# %%
print(plt.gcf()) # Get current figure
# Out:
# Figure(640x480)

# %%
print(plt.gca()) # Get current axes
plt.show()
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
plt.plot([1, 2, 3,4], [1,8,2,16])
plt.ylabel('Numbers')
plt.show() # red circles

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3,4], [1,8,27,64])
plt.show() # blue circles

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()
plt.show()  # Show the plot with legend

# %%
plt.plot([1, 2, 3,4], [1,4,9,16], 'ro')  # red circles
plt.axis([0, 6, 0, 20])  # Set axis limits
plt.show()  # Show the plot with specified axis limits

# %%
t = np.arange(0.,5., 0.02)

plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()  # Show the plot with different styles

# %%
fig, ax = plt.subplots()

ax.plot(x1, np.sin(x1), 'b-')
ax.plot(x1, np.cos(x1), 'b-');
plt.show()  # Show the plot with subplots

# %%
fig = plt.figure()

x2 = np.linspace(0, 5, 100)
y2 = x2 ** 2

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])  # [left, bottom, width, height]

axes.plot(x2, y2, 'r')

axes.set_xlabel('x2')
axes.set_ylabel('y2')
axes.set_title('title');
plt.show()  # Show the figure with custom axes

# %%
fig = plt.figure()

ax = plt.axes()
plt.show()  # Show the figure with default axes

# %%
plt.plot([1, 3, 2, 4], 'b')
plt.show()  # Show the plot with blue line])

# %%
x3 = np.arange(0.0, 6.0, 0.01)

plt.plot(x3, [xi**2 for xi in x3], 'b-')

plt.show()  # Show the plot with blue line

# %%
x4 = range(1, 5)

plt.plot(x4, [xi**1.5 for xi in x4])

plt.plot(x4, [xi*3 for xi in x4])

plt.plot(x4, [xi/3.0 for xi in x4])
plt.show()  # Show the plot with multiple lines

# %%
fig.savefig('plot1.png')  # Save the figure to a file

# %%
from IPython.display import Image

Image('plot1.png') # Display the saved image

# %%
fig.canvas.get_supported_filetypes()  # Get supported file types for saving
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %%
fig = plt.figure()

ax = plt.axes()

x5 = np.linspace(0, 10, 100)

ax.plot(x5, np.sin(x5), 'b-');

# %%
plt.show()  # Show the plot with sine function

# %%
x7 = np.linspace(0, 10, 30)

y7 = np.sin(x7)

plt.plot(x7, y7, 'o', color = 'black');

# %%
plt.show()  # Show the plot with sine function

# %%
data1 = np.random.randn(1000)

plt.hist(data1);

# %%
plt.show()  # Show the plot with sine function

# %%
data2 = [5., 25., 50., 20.]
plt.bar(range(len(data2)), data2)
plt.show()  # Show the bar plot

# %%
data2 = [5., 25., 50., 20.]
plt.barh(range(len(data2)), data2)
plt.show()  # Show the horizontal bar plot

# %%
x9 = np.arange(0, 4, 0.2)

y9 = np.exp(-x9)

e1 = 0.1 * np.abs(np.random.randn(len(y9)))

plt.errorbar(x9, y9, yerr = e1, fmt = '.-')
plt.show();

# %%
A = [15., 30., 45., 22.]
B = [15., 25., 50., 20.]
z2 = range(4)
plt.bar(z2, A, color = 'b')
plt.bar(z2, B, color = 'r', bottom = A)
plt.show()  # Show the stacked bar plot

# %%
plt.figure(figsize=(7,7))
x10 = [35,25,20,20]
labels = ['Computer', 'Electronics', 'Mechanical', 'Chemical']
plt.pie(x10, labels=labels);
plt.show()  # Create a new figure with specified size

# %%
data3 = np.random.randn(100)
plt.boxplot(data3)
plt.show()  # Show the box plot

# %%
x12 = range(1, 6)
y12 = [1, 4, 6, 8, 4]

plt.fill_between(x12, y12)
plt.show()  # Show the filled area plot

# %%
matrix1 = np.random.rand(10, 20)
cp = plt.contour(matrix1)
plt.show()  # Show the matrix plot

# %%
print(plt.style.available)  # List available styles
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
x15 = np.arange(1, 5)
plt.plot(x15, x15*1.5, x15, x15*3.0, x15, x15*3.0)
plt.grid(True)  # Add grid to the plot
plt.show()  # Show the plot with grid

# %%
x15 = np.arange(1 , 5)
plt.plot(x15, x15*1.5, x15, x15*3.0, x15, x15/3.0)
plt.axis([0, 5, -1, 13])
plt.show()  # Show the plot with specified axis limits

# %%
x15 = np.arange(1, 5)
plt.plot(x15, x15*1.5, x15, x15*3.0, x15, x15/3.0)
plt.xlim([1.0, 4.0])
plt.ylim([0.0, 12.0])
plt.show()  # Show the plot with specified x and y limits

# %%
u = [5, 4, 9, 7, 8, 9 , 6, 5, 7, 8]
plt.plot(u)
plt.xticks([2, 4, 6, 8, 10])
plt.yticks([2, 4, 6, 8, 10])
plt.show()  # Show the plot with custom ticks

# %%
plt.plot([1, 3, 2, 4])
plt.xlabel('This is the X axis')
plt.ylabel('This is the Y axis')
plt.show()  # Show the plot with labeled axes

# %%
plt.plot([1, 3, 2, 4])
plt.title('First Plot')
plt.show()  # Show the plot with title

# %%
x15 = np.arange(1, 5)

fig, ax = plt.subplots()

ax.plot(x15, x15*1.5)
ax.plot(x15, x15*3.0)
ax.plot(x15, x15/3.0)

ax.legend(['Normal', 'Fast', 'Slow'])
plt.show()  # Show the plot with legend

# %%
x15 = np.arange(1, 5)
fig,ax = plt.subplots() 
ax.plot(x15, x15*1.5, label='Normal')
ax.plot(x15, x15*3.0, label='Fast')
ax.plot(x15, x15/3.0, label='Slow')
ax.legend()
plt.show()  # Show the plot with legend and labels

# %%
x16 = np.arange(1, 5)
plt.plot(x16, 'r')
plt.plot(x16+1, 'g')
plt.plot(x16+2, 'b')
plt.show()  # Show the plot with different colors

# %%
x16 = np.arange(1, 5)
plt.plot(x16, '--',x16+1, '-.', x16+2, ':')
plt.show()  # Show the plot with different line styles

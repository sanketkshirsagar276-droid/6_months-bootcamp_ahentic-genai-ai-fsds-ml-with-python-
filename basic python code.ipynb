# %%
import matplotlib.pyplot as plt

# %%
'hello world'
# Out:
# 'hello world'

# %%
import numpy as np

# %%
x = np.arange(0,10)
y = 2*x+3
plt.plot(x,y)

# %%
x = np.arange(0,10)
y = x**2
plt.plot(x,y,ls='--',c='r')

# %%
x = np.arange(0,10)
label1='x'
label2='x**2'
plt.plot(x,ls='--',c='r',label=label1)
plt.plot(y,ls='--',c='g',label=label2)
plt.legend()

# %%
plt.title('My First Graph')
plt.xlabel('X Values')
plt.ylabel('Y Values')
x = np.arange(0,10)
label1='x'
label2='x**2'
plt.plot(x,ls='--',c='r',label=label1)
plt.plot(y,ls='--',c='g',label=label2)
plt.legend()

# %%
plt.title('My First Graph')
plt.xlabel('X Values')
plt.ylabel('Y Values')
x = np.arange(0,10)
label1='x'
label2='x**2'
plt.plot(x,ls='--',c='r',label=label1)
plt.plot(y,ls='--',c='g',label=label2)
plt.legend()
plt.savefig("my_plot.png")
plt.show()

# %%
x = np.random.rand(10)
y = np.random.rand(10)
plt.scatter(x,y, c='b', marker='o')
plt.title('My First Graph')
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.show()

# %%
x = np.random.rand(10)
y = np.random.rand(10)
plt.scatter(x,y, c='b', marker='o')

# %%
x = np.random.rand(10)
y = np.random.rand(10)
plt.scatter(x,y)

# %%
x = np.arange(0,10)
y = np.sin(x)
plt.plot(y,marker='o')

# %%
x = np.linspace(0,10,10)
y = x**2
plt.plot(x,y, c='g', marker='s', ls='--')
plt.title("Green Line with Square Markers")
plt.xlabel("X Values")
plt.ylabel("Y Values")

plt.show()

# %%
x = np.linspace(0,10,10)
y = x**2
plt.plot(x,y, c='g', marker='s', ls='--')

# %%
a = np.arange(0,10)
y = x
y1 = x**2

fig, ax = plt.subplots(1,2, figsize = (10,4))
ax[0].plot(a,y, c='g', ls='--', marker='o')
ax[0].set_title('my graph')

ax[1].plot(y1, c='b', ls='--', marker='s')
ax[1].set_title('my graph')
# Out:
# Text(0.5, 1.0, 'my graph')
